# %%
# !pip install torch torch_geometric

import torch
import torch.nn as nn
from torch_geometric.nn import GATConv
from torch_geometric.data import Data
# Out:
# Collecting torch
#   Downloading torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
#      |████████████████████████████████| 619.9 MB 13 kB/s  eta 0:00:01
# Collecting torch_geometric
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#      |████████████████████████████████| 661 kB 1.2 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 821 kB/s eta 0:00:01
# Requirement already satisfied: sympy in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch) (1.9)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 2.3 MB/s eta 0:00:01
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 2.3 MB/s eta 0:00:01
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      |████████████████████████████████| 317.1 MB 50 kB/s  eta 0:00:014
# Collecting nvidia-nvtx-cu11==11.7.91
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      |████████████████████████████████| 98 kB 898 kB/s eta 0:00:01
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      |████████████████████████████████| 168.4 MB 95 kB/s  eta 0:00:01
# Requirement already satisfied: jinja2 in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch) (2.11.3)
# Requirement already satisfied: typing-extensions in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch) (4.6.1)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      |████████████████████████████████| 557.1 MB 10 kB/s  eta 0:00:01
# Requirement already satisfied: networkx in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch) (2.6.3)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      |████████████████████████████████| 173.2 MB 48 kB/s  eta 0:00:01
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      |████████████████████████████████| 102.6 MB 2.0 MB/s eta 0:00:01
# Collecting nvidia-curand-cu11==10.2.10.91
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      |████████████████████████████████| 54.6 MB 382 kB/s eta 0:00:01
# Requirement already satisfied: filelock in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch) (3.3.1)
# Collecting triton==2.0.0
#   Downloading triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      |████████████████████████████████| 63.3 MB 4.3 MB/s eta 0:00:01
# Collecting nvidia-nccl-cu11==2.14.3
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      |████████████████████████████████| 177.1 MB 68 kB/s  eta 0:00:01     |█████████████████████████▏      | 139.3 MB 5.1 MB/s eta 0:00:08
# Requirement already satisfied: setuptools in /home/makbay/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (58.0.4)
# Requirement already satisfied: wheel in /home/makbay/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.0)
# Collecting cmake
#   Downloading cmake-3.26.3-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      |████████████████████████████████| 24.0 MB 5.7 MB/s eta 0:00:01
# Collecting lit
#   Downloading lit-16.0.5.tar.gz (138 kB)
#      |████████████████████████████████| 138 kB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: requests in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch_geometric) (2.26.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch_geometric) (5.8.0)
# Requirement already satisfied: scipy in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch_geometric) (1.7.1)
# Requirement already satisfied: pyparsing in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch_geometric) (3.0.4)
# Requirement already satisfied: tqdm in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch_geometric) (4.62.3)
# Requirement already satisfied: numpy in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch_geometric) (1.22.4)
# Requirement already satisfied: scikit-learn in /home/makbay/anaconda3/lib/python3.9/site-packages (from torch_geometric) (0.24.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/makbay/anaconda3/lib/python3.9/site-packages (from jinja2->torch) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/makbay/anaconda3/lib/python3.9/site-packages (from requests->torch_geometric) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/makbay/anaconda3/lib/python3.9/site-packages (from requests->torch_geometric) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/makbay/anaconda3/lib/python3.9/site-packages (from requests->torch_geometric) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/makbay/anaconda3/lib/python3.9/site-packages (from requests->torch_geometric) (3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/makbay/anaconda3/lib/python3.9/site-packages (from scikit-learn->torch_geometric) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /home/makbay/anaconda3/lib/python3.9/site-packages (from scikit-learn->torch_geometric) (1.1.0)
# Requirement already satisfied: mpmath>=0.19 in /home/makbay/anaconda3/lib/python3.9/site-packages (from sympy->torch) (1.2.1)
# Building wheels for collected packages: torch-geometric, lit
#   Building wheel for torch-geometric (PEP 517) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910459 sha256=2f32e2ea77888bd0d83a498dd2e1ba4a4d66d6483c7e90052dd335879ee8f298
#   Stored in directory: /home/makbay/.cache/pip/wheels/75/cc/0c/029f33b5cb29c590a061faf5202ea24956388bba7f1af50f2e
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.5-py3-none-any.whl size=88192 sha256=162e98465c95d63d9c4f4cbfc42d2d57de79a2500ed349e284a45e67c03db132
#   Stored in directory: /home/makbay/.cache/pip/wheels/d8/3a/a1/643264c1075b22759205027b760e0b1e85d975bfb333eef328
# Successfully built torch-geometric lit
# Installing collected packages: nvidia-cublas-cu11, lit, cmake, triton, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-cusolver-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, torch-geometric, torch
# Successfully installed cmake-3.26.3 lit-16.0.5 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 torch-geometric-2.3.1 triton-2.0.0

# %%
class GNNModel(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(GNNModel, self).__init__()
        self.conv1 = GATConv(input_dim, hidden_dim)
        self.conv2 = GATConv(hidden_dim, hidden_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = nn.ReLU()(x)
        x = self.conv2(x, edge_index)
        return x
